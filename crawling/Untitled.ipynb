# %%
log='C:/Users/chaeh/Desktop/ChaeheePark/NH_Bigdata_Contest/data/iem_info_20210902.csv'
import pandas as pd

iem=pd.read_csv(log)

# %%
iem
# Out:
#        iem_cd             iem_krl_nm  btp_cfc_cd  mkt_pr_tal_scl_tp_cd  \
# 0     A000020                   동화약품           8                     2
# 1     A000080                  하이트진로          14                     2
# 2     A000180                 성창기업지주           5                     3
# 3     A000227                유유제약2우B           8                    99
# 4     A000325                 노루홀딩스우           2                    99
# ...       ...                    ...         ...                   ...
# 3074  A383310               에코프로에이치엔          14                    99
# 3075  A385520         KODEX K-미래차액티브          14                    99
# 3076  A388280         KBSTAR Fn컨택트대표          14                    99
# 3077  A388420      KBSTAR 비메모리반도체액티브          14                    99
# 3078  A394350  KOSEF 릭소글로벌퓨처모빌리티MSCI          14                    99
#
#       stk_dit_cd
# 0             99
# 1              1
# 2             99
# 3             99
# 4             99
# ...

# %%
# A065370	위세아이텍	10	3	99까지
